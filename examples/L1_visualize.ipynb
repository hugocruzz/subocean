# %%
import pandas as pd

# %%
import xarray as xr
#OPen all .nc files in data/Level1 folder
ds = xr.open_dataset("../data/Level1/combined_profiles.nc")

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                                            (datetime: 8213,
#                                                         profile: 5)
# Coordinates:
#   * datetime                                           (datetime) datetime64[ns] ...
# Dimensions without coordinates: profile
# Data variables: (12/34)
#     Date_calibrated                                    (profile, datetime) object ...
#     Time_calibrated                                    (profile, datetime) object ...
#     CH4_dissolved_with_water_vapour_ppm                (profile, datetime) float64 ...
#     CH4_dissolved_with_water_vapour_nmolperL           (profile, datetime) float64 ...
#     CH4_dissolved_with_constant_dry_gas_flow_ppm       (profile, datetime) float64 ...
#     CH4_dissolved_with_constant_dry_gas_flow_nmolperL  (profile, datetime) float64 ...
#     ...                                                 ...
# ...

# %%
ds.variables
# Out:
# Frozen({'datetime': <xarray.IndexVariable 'datetime' (datetime: 8213)>
# array(['2024-11-27T12:58:45.000000000', '2024-11-27T12:58:46.000000000',
#        '2024-11-27T12:58:47.000000000', ..., '2024-12-11T12:31:09.000000000',
#        '2024-12-11T12:31:10.000000000', '2024-12-11T12:31:11.000000000'],
#       dtype='datetime64[ns]'), 'Date_calibrated': <xarray.Variable (profile: 5, datetime: 8213)>
# [41065 values with dtype=object], 'Time_calibrated': <xarray.Variable (profile: 5, datetime: 8213)>
# [41065 values with dtype=object], 'CH4_dissolved_with_water_vapour_ppm': <xarray.Variable (profile: 5, datetime: 8213)>
# [41065 values with dtype=float64], 'CH4_dissolved_with_water_vapour_nmolperL': <xarray.Variable (profile: 5, datetime: 8213)>
# [41065 values with dtype=float64], 'CH4_dissolved_with_constant_dry_gas_flow_ppm': <xarray.Variable (profile: 5, datetime: 8213)>
# ...

# %%
ds.Depth_meter
# Out:
# <xarray.DataArray 'Depth_meter' (profile: 5, datetime: 8213)>
# [41065 values with dtype=float64]
# Coordinates:
#   * datetime  (datetime) datetime64[ns] 2024-11-27T12:58:45 ... 2024-12-11T12...
# Dimensions without coordinates: profile
